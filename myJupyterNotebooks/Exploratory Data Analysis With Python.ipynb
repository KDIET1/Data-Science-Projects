# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
import seaborn as sns

# %%
diamonds = sns.load_dataset('diamonds')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)

sns.kdeplot(diamonds['carat'], shade=True)

plt.axvline(diamonds['carat'].mean(), 0, 1)
plt.axvline(diamonds['carat'].median(), 0, 1, color='r')

# %%
diamonds.dtypes
# Out:
# carat       float64
# cut        category
# color      category
# clarity    category
# depth       float64
# table       float64
# price         int64
# x           float64
# y           float64
# z           float64
# dtype: object

# %%
carat = 'carat'
table = 'table'

# %%
#This is my one-way ANOVA Univariate Analysis Test. I chose these three variables because they were all the same data types
stats.f_oneway(diamonds['carat'][diamonds['carat'] == 'x'], diamonds['depth'][diamonds['depth'] == 'y'], diamonds['table'][diamonds['table'] == 'z'] )
# Out:
# F_onewayResult(statistic=nan, pvalue=nan)

# %%
#Covariance Multivariate Analysis
np.cov(diamonds['carat'], diamonds['table'])
# Out:
# array([[0.22468666, 0.19236452],
#        [0.19236452, 4.99294808]])

# %%
diamonds.cov()
# Out:
#              carat      depth        table         price            x  \
# carat     0.224687   0.019167     0.192365  1.742765e+03     0.518484
# depth     0.019167   2.052404    -0.946840 -6.085371e+01    -0.040641
# table     0.192365  -0.946840     4.992948  1.133318e+03     0.489643
# price  1742.765364 -60.853712  1133.318064  1.591563e+07  3958.021491
# x         0.518484  -0.040641     0.489643  3.958021e+03     1.258347
# y         0.515248  -0.048009     0.468972  3.943271e+03     1.248789
# z         0.318917   0.095968     0.237996  2.424713e+03     0.768487
#
#                  y            z
# carat     0.515248     0.318917
# depth    -0.048009     0.095968
# table     0.468972     0.237996
# price  3943.270810  2424.712613
# x         1.248789     0.768487
# y         1.304472     0.767320
# z         0.767320     0.498011

# %%
#Correlation Multivariate Analysis
np.corrcoef(diamonds['carat'], diamonds['table'])
# Out:
# array([[1.        , 0.18161755],
#        [0.18161755, 1.        ]])

# %%
#scatterplot Multivariate Analysis
fig, ax=plt.subplots(figsize=(10.5, 7.2))
sns.scatterplot(x='carat', y='table', data=diamonds, color='#F15B2A')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='table'>

# %%
#bubbleplot Multivariate Analysis
x = np.random.rand(40)
y = np.random.rand(40)
z = np.random.rand(40)

x = diamonds.carat
y = diamonds.table
z = np.arange(len(x))

fig = plt.figure(figsize=(10.5, 7.2))
plt.scatter(x, y, s=z*1.5, alpha=0.5, c='#F15B2A')

# %%
#Multivariate analysis composition plot unrelated to the Diamonds dataset 
x = range(1, 6)
y = [[1,4,6,8,9], [2,2,7,10,12], [2,8,5,10,6]]

fig=plt.figure(figsize=(10.5, 7.2))
plt.stackplot(x,y, labels=['A', 'B', 'C'], baseline='zero')
plt.legend(loc='upper left')
